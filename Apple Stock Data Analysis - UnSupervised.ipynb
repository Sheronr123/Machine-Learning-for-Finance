# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import r2_score

# %%
df = pd.read_csv('apple_stock_prepared.csv')
df
# Out:
#        volume  close_lag1  close_lag2  close_lag3  close_lag4  close_lag5  \
# 0   -0.464011   -0.767950   -0.747017   -0.739101   -0.639217   -0.669514
# 1   -0.190969   -0.769480   -0.758587   -0.738967   -0.732728   -0.632766
# 2   -0.723175   -0.760056   -0.760125   -0.750631   -0.732592   -0.727153
# 3   -0.570132   -0.763094   -0.750650   -0.752182   -0.744357   -0.727016
# 4   -0.692599   -0.760123   -0.753705   -0.742630   -0.745922   -0.738891
# ..        ...         ...         ...         ...         ...         ...
# 191 -0.793550    1.604636    1.763441    1.671463    1.504886    1.711946
# 192 -0.918149    1.871598    1.626894    1.791975    1.698640    1.531433
# 193 -1.143272    1.849092    1.895306    1.654314    1.820192    1.727003
# 194 -0.646054    1.910400    1.872678    1.924917    1.681343    1.849694
# 195 -0.818447    1.685345    1.934320    1.902104    1.954281    1.709544
#
#      close_lag6      ma_3     rsi_3      ma_6     rsi_6      ma_9     rsi_9  \
# 0     -0.646494  0.627785 -1.812133  4.368171 -1.830292  7.716514 -1.862736
# 1     -0.662760 -0.579982 -1.183392  1.505926 -1.592107  3.501353 -1.710687
# 2     -0.625758 -0.115027 -1.286573  0.152772 -1.626297  2.429129 -1.732050
# 3     -0.720797 -0.092085 -0.982726 -0.217920 -1.529132  1.347659 -1.674853
# 4     -0.720659 -0.694639 -0.034087 -0.992704 -1.141034 -0.009939 -1.444629
# ..          ...       ...       ...       ...       ...       ...       ...
# 191    1.630468 -0.223795  0.546643 -0.331446  0.673720 -0.357578  0.629509
# 192    1.735137 -0.123015  0.374026 -0.224093  0.567415 -0.253361  0.557737
# 193    1.553377 -0.050645  0.580333 -0.185932  0.686190 -0.255568  0.650124
# 194    1.750297  0.248055 -0.952595  0.233958 -0.332910  0.084071 -0.061402
# 195    1.873836 -0.142245  0.138432 -0.144389  0.267664 -0.202888  0.363149
#
#         ma_12    rsi_12     event       close
# 0    8.506598 -1.880503 -0.456953    2.338571
# 1    5.255354 -1.767605 -0.456953    2.945714
# 2    4.553852 -1.782792 -0.456953    2.750000
# 3    2.875177 -1.742103 -0.456953    2.941429
# 4    1.005462 -1.579137 -0.456953    3.678571
# ..        ...       ...       ...         ...
# 191 -0.408869  0.485557 -0.456953  172.500000
# 192 -0.309700  0.438452 -0.456953  171.050000
# 193 -0.289776  0.511566 -0.456953  175.000000
# 194 -0.031482  0.031806 -0.456953  160.500000
# 195 -0.219850  0.349066  2.177245  176.210000
#
# [196 rows x 17 columns]

# %%
X = df.loc[:, df.columns!='close']
y = df['close']

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,random_state=43,test_size=0.2)

# %%
dtr = DecisionTreeRegressor(max_depth = 2, min_samples_split=5)
dtr.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(max_depth=2, min_samples_split=5)

# %%
y_train_pred = dtr.predict(X_train)

# %%
r2_score(y_train, y_train_pred)
# Out:
# 0.9353866914788659

# %%
y_test_pred = dtr.predict(X_test)

# %%
r2_score(y_test, y_test_pred)
# Out:
# 0.8966385965557828

# %%
def train_and_plot_tree(X_train, y_train, X_test, y_test, max_depth = 2):
    dtr = DecisionTreeRegressor(max_depth = max_depth)
    dtr.fit(X_train,y_train)
    y_train_pred = dtr.predict(X_train)
    r2 = r2_score(y_train, y_train_pred)
    y_test_pred = dtr.predict(X_test)
    r2_test = r2_score(y_test, y_test_pred)
    print("R Squared on train data: ", r2)
    print("R Squared on test data: ", r2_test)
    features = list(X.columns)
    plt.figure(figsize=[20,14])
    tree.plot_tree(dtr, feature_names=features, filled=True)
    plt.show()

# %%
train_and_plot_tree(X_train, y_train, X_test, y_test, max_depth = 2)
# Out:
# R Squared on train data:  0.9353866914788659
# R Squared on test data:  0.8966385965557828
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 train_and_plot_tree(X_train, y_train, X_test, y_test, max_depth = 2)
#
# Cell In[10], line 12, in train_and_plot_tree(X_train, y_train, X_test, y_test, max_depth)
#      10 features = list(X.columns)
#      11 plt.figure(figsize=[20,14])
# ---> 12 tree.plot_tree(dtr, feature_names=features, filled=True)
#      13 plt.show()
#
# NameError: name 'tree' is not defined

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rfr = RandomForestRegressor(random_state = 100, oob_score=True, max_features = 'sqrt')
rfr.fit(X_train, y_train)

# %%
1-rfr.oob_score_

# %%
y__rfr_pred = rfr.predict(X_test)

# %%
print('Train r2 score:', r2_score(y_train, rfr.predict(X_train)))

# %%
print('Test r2 score:', r2_score(y_test, y__rfr_pred))

# %%
features = X_train.columns
importances = rfr.feature_importances_
indices = np.argsort(importances)
plt.figure(figsize=(16,10))
plt.title('Feature Importances')
plt.barh(range(len(indices)), importances[indices], color='b', align='center')
plt.yticks(range(len(indices)), [features[i] for i in indices])
plt.xlabel('Relative Importance')
plt.show()

# %%
# XGBoost Model:

# %%
from xgboost import XGBRegressor

# %%
xgr = XGBRegressor()

# %%
xgr.fit(X_train, y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=None, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
y_xgr_pred = xgr.predict(X_test)

# %%
print('Train r2 score:', r2_score(y_train, xgr.predict(X_train)))
print('Test r2 score:', r2_score(y_test, y_xgr_pred))
# Out:
# Train r2 score: 0.9999999998051546
# Test r2 score: 0.9903967259109525
